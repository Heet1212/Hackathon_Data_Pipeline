# %%
# with function
import json

def check_duplicate_ids(file_path):
    try:
        data = json.load(open(file_path, 'r'))
    except FileNotFoundError:
        print(f"File not found at path: {file_path}")
        return

    total_id_count = 0
    unique_ids = set()
    duplicate_ids = set()

    for item in data:
        item_id = item.get("id")
        if item_id:
            if item_id in unique_ids:
                duplicate_ids.add(item_id)
            else:
                unique_ids.add(item_id)
            total_id_count += item_id

    total_unique_ids = len(unique_ids)
    total_duplicate_ids = len(duplicate_ids)

    print(f"Total unique 'id' values: {total_unique_ids}")
    print(f"Total duplicate 'id' values: {total_duplicate_ids}")
    print(f"Total 'id' count in key 'id': {total_id_count}")

    if duplicate_ids:
        print("Duplicate 'id' values found:")
        for id in duplicate_ids:
            print(id)

# Example usage:
file_path = '/content/user_data.json'
check_duplicate_ids(file_path)
# Out:
# Total unique 'id' values: 1000
# Total duplicate 'id' values: 0
# Total 'id' count in key 'id': 500500

# %%
import json

def remove_duplicate_ids_and_ip_addresses(input_file_path, output_file_path):
    # Load the JSON data from the input file
    with open(input_file_path, "r") as json_file:
        data = json.load(json_file)

    # Create sets to store unique "id" and "ip_address" values
    unique_ids = set()
    unique_ip_addresses = set()
    duplicates_removed_data = []

    # Iterate through the JSON data and check for duplicate "id" and "ip_address" values
    for item in data:
        item_id = item.get("id")
        item_ip_address = item.get("ip_address")

        if item_id:
            if item_id not in unique_ids:
                unique_ids.add(item_id)
            else:
                continue  # Skip items with duplicate "id" values

        if item_ip_address:
            if item_ip_address not in unique_ip_addresses:
                unique_ip_addresses.add(item_ip_address)
            else:
                continue  # Skip items with duplicate "ip_address" values

        # If both "id" and "ip_address" are unique, add the item to the new data list
        duplicates_removed_data.append(item)

    # Write the new JSON data with duplicates removed to the output file
    with open(output_file_path, "w") as new_json_file:
        json.dump(duplicates_removed_data, new_json_file, indent=4)

    return output_file_path

# Usage example
input_file_path = "/content/user_data.json"
output_file_path = "/content/filtered_data.json"
new_file_path = remove_duplicate_ids_and_ip_addresses(input_file_path, output_file_path)
print(f"Duplicate 'id' and 'ip_address' values removed. New JSON file saved as '{new_file_path}'")
# Out:
# Duplicate 'id' and 'ip_address' values removed. New JSON file saved as '/content/filtered_data.json'

# %%
data
# Out:
# [{'id': 1,
#   'first_name': 'Estrella',
#   'last_name': 'Lefley',
#   'email': 'elefley0@ifeng.com',
#   'gender': 'Female',
#   'ip_address': '203.78.236.252'},
#  {'id': 2,
#   'first_name': 'Jeth',
#   'last_name': 'Dukesbury',
#   'email': 'jdukesbury1@printfriendly.com',
#   'gender': 'Male',
#   'ip_address': '248.192.4.225'},
#  {'id': 3,
#   'first_name': 'Gareth',
#   'last_name': 'Pluck',
#   'email': 'gpluck2@fema.gov',
#   'gender': 'Male',
#   'ip_address': '105.105.231.37'},
#  {'id': 4,
#   'first_name': 'Donnajean',
#   'last_name': 'Lasslett',
#   'email': 'dlasslett3@scientificamerican.com',
#   'gender': 'Female',
#   'ip_address': '93.199.93.188'},
#  {'id': 5,
#   'first_name': 'Tremaine',
#   'last_name': 'Poxon',
#   'email': 'tpoxon4@mozilla.org',
#   'gender': 'Male',
#   'ip_address': '89.141.203.82'},
#  {'id': 6,
#   'first_name': 'Fons',
#   'last_name': 'Klosa',
#   'email': 'fklosa5@home.pl',
#   'gender': 'Male',
#   'ip_address': '109.103.187.211'},
#  {'id': 7,
#   'first_name': 'Irina',
#   'last_name': 'Howitt',
#   'email': 'ihowitt6@youtu.be',
#   'gender': 'Female',
#   'ip_address': '72.129.124.9'},
#  {'id': 8,
#   'first_name': 'Darb',
#   'last_name': 'Sheerman',
#   'email': 'dsheerman7@twitter.com',
#   'gender': 'Male',
#   'ip_address': '187.240.10.109'},
#  {'id': 9,
#   'first_name': 'Yvon',
#   'last_name': 'Gillings',
#   'email': 'ygillings8@buzzfeed.com',
#   'gender': 'Male',
#   'ip_address': '115.227.37.196'},
#  {'id': 10,
#   'first_name': 'Nelia',
#   'last_name': 'Witherdon',
#   'email': 'nwitherdon9@noaa.gov',
#   'gender': 'Female',
#   'ip_address': '135.232.51.103'},
#  {'id': 11,
#   'first_name': 'Korney',
#   'last_name': 'Milvarnie',
#   'email': 'kmilvarniea@springer.com',
#   'gender': 'Female',
#   'ip_address': '215.17.208.63'},
#  {'id': 12,
#   'first_name': 'Felice',
#   'last_name': 'Butchers',
#   'email': 'fbutchersb@macromedia.com',
#   'gender': 'Male',
#   'ip_address': '85.194.30.102'},
#  {'id': 13,
#   'first_name': 'Whitney',
#   'last_name': 'Clerk',
#   'email': 'wclerkc@rambler.ru',
#   'gender': 'Male',
#   'ip_address': '109.153.142.213'},
#  {'id': 14,
#   'first_name': 'Lishe',
#   'last_name': 'Hardy',
#   'email': 'lhardyd@auda.org.au',
#   'gender': 'Female',
#   'ip_address': '253.234.201.148'},
#  {'id': 15,
#   'first_name': 'Tabina',
#   'last_name': 'Scougall',
#   'email': 'tscougalle@linkedin.com',
#   'gender': 'Female',
#   'ip_address': '227.66.142.211'},
#  {'id': 16,
#   'first_name': 'Luis',
#   'last_name': 'Godfroy',
#   'email': 'lgodfroyf@utexas.edu',
#   'gender': 'Male',
#   'ip_address': '86.202.124.223'},
#  {'id': 17,
#   'first_name': 'Celinka',
#   'last_name': 'Palfreman',
#   'email': 'cpalfremang@bbb.org',
#   'gender': 'Female',
#   'ip_address': '213.112.162.140'},
#  {'id': 18,
#   'first_name': 'Sherwynd',
#   'last_name': 'Petroff',
#   'email': 'spetroffh@wikimedia.org',
#   'gender': 'Polygender',
#   'ip_address': '50.84.231.55'},
#  {'id': 19,
#   'first_name': 'Tabbitha',
#   'last_name': 'Scholling',
#   'email': 'tschollingi@ustream.tv',
#   'gender': 'Female',
#   'ip_address': '150.72.56.57'},
#  {'id': 20,
#   'first_name': 'Maryrose',
#   'last_name': 'Fickling',
#   'email': 'mficklingj@github.io',
#   'gender': 'Female',
#   'ip_address': '240.31.100.222'},
#  {'id': 21,
#   'first_name': 'Aubert',
#   'last_name': 'Drynan',
#   'email': 'adrynank@mediafire.com',
#   'gender': 'Male',
#   'ip_address': '166.126.68.85'},
#  {'id': 22,
#   'first_name': 'Travus',
#   'last_name': 'Babber',
#   'email': 'tbabberl@youku.com',
#   'gender': 'Male',
#   'ip_address': '1.45.125.229'},
#  {'id': 23,
#   'first_name': 'Ferdinanda',
#   'last_name': 'Cosgreave',
#   'email': 'fcosgreavem@army.mil',
#   'gender': 'Female',
#   'ip_address': '234.242.26.210'},
#  {'id': 24,
#   'first_name': 'Milicent',
#   'last_name': 'Nelthrop',
#   'email': 'mnelthropn@nba.com',
#   'gender': 'Female',
#   'ip_address': '185.153.128.89'},
#  {'id': 25,
#   'first_name': 'Mandy',
#   'last_name': 'Olenchenko',
#   'email': 'molenchenkoo@histats.com',
#   'gender': 'Female',
#   'ip_address': '225.38.120.254'},
#  {'id': 26,
#   'first_name': 'Elsbeth',
#   'last_name': 'Aronowitz',
#   'email': 'earonowitzp@yahoo.com',
#   'gender': 'Female',
#   'ip_address': '181.152.56.133'},
#  {'id': 27,
#   'first_name': 'Brinn',
#   'last_name': 'Wrathmell',
#   'email': 'bwrathmellq@aol.com',
#   'gender': 'Female',
#   'ip_address': '204.189.5.228'},
#  {'id': 28,
#   'first_name': 'Tabor',
#   'last_name': 'Olenchenko',
#   'email': 'tolenchenkor@omniture.com',
#   'gender': 'Polygender',
#   'ip_address': '21.96.144.3'},
#  {'id': 29,
#   'first_name': 'Job',
#   'last_name': 'Timmens',
#   'email': 'jtimmenss@macromedia.com',
#   'gender': 'Male',
#   'ip_address': '207.99.57.133'},
#  {'id': 30,
#   'first_name': 'Greg',
#   'last_name': 'Gelder',
#   'email': 'ggeldert@tiny.cc',
#   'gender': 'Male',
#   'ip_address': '29.106.48.134'},
#  {'id': 31,
#   'first_name': 'Cozmo',
#   'last_name': 'Durtnel',
#   'email': 'cdurtnelu@g.co',
#   'gender': 'Male',
#   'ip_address': '21.177.201.35'},
#  {'id': 32,
#   'first_name': 'Tandy',
#   'last_name': 'Credland',
#   'email': 'tcredlandv@blogtalkradio.com',
#   'gender': 'Female',
#   'ip_address': '21.121.231.126'},
#  {'id': 33,
#   'first_name': 'Josephina',
#   'last_name': 'Mapstone',
#   'email': 'jmapstonew@ucsd.edu',
#   'gender': 'Female',
#   'ip_address': '71.21.19.68'},
#  {'id': 34,
#   'first_name': 'Sherlocke',
#   'last_name': 'Dolby',
#   'email': 'sdolbyx@wiley.com',
#   'gender': 'Male',
#   'ip_address': '148.155.232.92'},
#  {'id': 35,
#   'first_name': 'Andy',
#   'last_name': 'Walford',
#   'email': 'awalfordy@walmart.com',
#   'gender': 'Male',
#   'ip_address': '129.247.233.10'},
#  {'id': 36,
#   'first_name': 'Gabriela',
#   'last_name': 'Quilliam',
#   'email': 'gquilliamz@is.gd',
#   'gender': 'Female',
#   'ip_address': '45.144.224.45'},
#  {'id': 37,
#   'first_name': 'Osmond',
#   'last_name': 'Dumbarton',
#   'email': 'odumbarton10@msn.com',
#   'gender': 'Male',
#   'ip_address': '143.6.221.44'},
#  {'id': 38,
#   'first_name': 'Lilllie',
#   'last_name': 'Durn',
#   'email': 'ldurn11@tuttocitta.it',
#   'gender': 'Female',
#   'ip_address': '205.86.190.157'},
#  {'id': 39,
#   'first_name': 'Kandace',
#   'last_name': 'Zywicki',
#   'email': 'kzywicki12@google.com',
#   'gender': 'Female',
#   'ip_address': '233.205.194.236'},
#  {'id': 40,
#   'first_name': 'Nerta',
#   'last_name': 'Pelosi',
#   'email': 'npelosi13@icq.com',
#   'gender': 'Female',
#   'ip_address': '38.108.245.76'},
#  {'id': 41,
#   'first_name': 'Regan',
#   'last_name': 'Hazeldene',
#   'email': 'rhazeldene14@fema.gov',
#   'gender': 'Male',
#   'ip_address': '177.16.63.102'},
#  {'id': 42,
#   'first_name': 'Tiebout',
#   'last_name': 'Punter',
#   'email': 'tpunter15@liveinternet.ru',
#   'gender': 'Bigender',
#   'ip_address': '158.103.124.104'},
#  {'id': 43,
#   'first_name': 'Jane',
#   'last_name': 'Loker',
#   'email': 'jloker16@furl.net',
#   'gender': 'Female',
#   'ip_address': '116.56.31.130'},
#  {'id': 44,
#   'first_name': 'Blondy',
#   'last_name': 'Riddall',
#   'email': 'briddall17@oaic.gov.au',
#   'gender': 'Female',
#   'ip_address': '59.174.218.29'},
#  {'id': 45,
#   'first_name': 'Kenton',
#   'last_name': 'Lithgow',
#   'email': 'klithgow18@last.fm',
#   'gender': 'Male',
#   'ip_address': '155.62.246.250'},
#  {'id': 46,
#   'first_name': 'Aloise',
#   'last_name': 'Yersin',
#   'email': 'ayersin19@last.fm',
#   'gender': 'Female',
#   'ip_address': '120.249.242.38'},
#  {'id': 47,
#   'first_name': 'Vinni',
#   'last_name': 'Larkkem',
#   'email': 'vlarkkem1a@arizona.edu',
#   'gender': 'Female',
#   'ip_address': '168.50.145.205'},
#  {'id': 48,
#   'first_name': 'Hillary',
#   'last_name': 'Teal',
#   'email': 'hteal1b@friendfeed.com',
#   'gender': 'Genderqueer',
#   'ip_address': '184.117.161.186'},
#  {'id': 49,
#   'first_name': 'Noemi',
#   'last_name': 'Bowlesworth',
#   'email': 'nbowlesworth1c@smh.com.au',
#   'gender': 'Female',
#   'ip_address': '87.193.49.11'},
#  {'id': 50,
#   'first_name': 'Joshia',
#   'last_name': 'Lugg',
#   'email': 'jlugg1d@1688.com',
#   'gender': 'Male',
#   'ip_address': '232.104.144.15'},
#  {'id': 51,
#   'first_name': 'Kipp',
#   'last_name': 'Maes',
#   'email': 'kmaes1e@bloglovin.com',
#   'gender': 'Male',
#   'ip_address': '204.245.176.126'},
#  {'id': 52,
#   'first_name': 'Angil',
#   'last_name': 'Garnsworth',
#   'email': 'agarnsworth1f@merriam-webster.com',
#   'gender': 'Female',
#   'ip_address': '93.48.71.191'},
#  {'id': 53,
#   'first_name': 'Reynold',
#   'last_name': 'McTavy',
#   'email': 'rmctavy1g@cornell.edu',
#   'gender': 'Male',
#   'ip_address': '250.47.12.112'},
#  {'id': 54,
#   'first_name': 'Vivien',
#   'last_name': 'MacCoughan',
#   'email': 'vmaccoughan1h@businesswire.com',
#   'gender': 'Female',
#   'ip_address': '84.238.44.90'},
#  {'id': 55,
#   'first_name': 'Etienne',
#   'last_name': 'Sabater',
#   'email': 'esabater1i@huffingtonpost.com',
#   'gender': 'Male',
#   'ip_address': '144.173.121.134'},
#  {'id': 56,
#   'first_name': 'Elia',
#   'last_name': 'Dawley',
#   'email': 'edawley1j@state.tx.us',
#   'gender': 'Male',
#   'ip_address': '117.78.9.117'},
#  {'id': 57,
#   'first_name': 'Karlene',
#   'last_name': 'Dumbleton',
#   'email': 'kdumbleton1k@umn.edu',
#   'gender': 'Female',
#   'ip_address': '255.189.154.96'},
#  {'id': 58,
#   'first_name': 'Jerrie',
#   'last_name': 'Cotman',
#   'email': 'jcotman1l@reuters.com',
#   'gender': 'Female',
#   'ip_address': '9.71.162.81'},
#  {'id': 59,
#   'first_name': 'Nils',
#   'last_name': 'Pandie',
#   'email': 'npandie1m@soundcloud.com',
#   'gender': 'Male',
#   'ip_address': '185.248.66.102'},
#  {'id': 60,
#   'first_name': 'Emile',
#   'last_name': 'Pester',
#   'email': 'epester1n@biglobe.ne.jp',
#   'gender': 'Male',
#   'ip_address': '195.2.42.98'},
#  {'id': 61,
#   'first_name': 'Cart',
#   'last_name': 'Firman',
#   'email': 'cfirman1o@bloglovin.com',
#   'gender': 'Male',
#   'ip_address': '180.232.197.145'},
#  {'id': 62,
#   'first_name': 'Alyss',
#   'last_name': 'Breton',
#   'email': 'abreton1p@icio.us',
#   'gender': 'Female',
#   'ip_address': '239.54.82.85'},
#  {'id': 63,
#   'first_name': 'Morena',
#   'last_name': 'Virgoe',
#   'email': 'mvirgoe1q@xing.com',
#   'gender': 'Female',
#   'ip_address': '39.110.65.184'},
#  {'id': 64,
#   'first_name': 'Hasty',
#   'last_name': 'Gillam',
#   'email': 'hgillam1r@twitter.com',
#   'gender': 'Male',
#   'ip_address': '202.212.44.8'},
#  {'id': 65,
#   'first_name': 'Tracey',
#   'last_name': 'Worviell',
#   'email': 'tworviell1s@networksolutions.com',
#   'gender': 'Male',
#   'ip_address': '213.216.7.154'},
#  {'id': 66,
#   'first_name': 'Reider',
#   'last_name': 'Seden',
#   'email': 'rseden1t@nydailynews.com',
#   'gender': 'Male',
#   'ip_address': '41.180.98.49'},
#  {'id': 67,
#   'first_name': 'Maxie',
#   'last_name': 'Vial',
#   'email': 'mvial1u@google.com',
#   'gender': 'Male',
#   'ip_address': '75.237.194.116'},
#  {'id': 68,
#   'first_name': 'Sebastiano',
#   'last_name': 'Kember',
#   'email': 'skember1v@netvibes.com',
#   'gender': 'Male',
#   'ip_address': '220.48.38.1'},
#  {'id': 69,
#   'first_name': 'Sheba',
#   'last_name': 'Yushkin',
#   'email': 'syushkin1w@canalblog.com',
#   'gender': 'Female',
#   'ip_address': '131.182.88.137'},
#  {'id': 70,
#   'first_name': 'Vince',
#   'last_name': 'Flagg',
#   'email': 'vflagg1x@nba.com',
#   'gender': 'Male',
#   'ip_address': '102.58.175.104'},
#  {'id': 71,
#   'first_name': 'Alexandro',
#   'last_name': 'Bernot',
#   'email': 'abernot1y@hatena.ne.jp',
#   'gender': 'Male',
#   'ip_address': '135.40.198.187'},
#  {'id': 72,
#   'first_name': 'Bondon',
#   'last_name': 'Karpe',
#   'email': 'bkarpe1z@youku.com',
#   'gender': 'Male',
#   'ip_address': '186.2.195.230'},
#  {'id': 73,
#   'first_name': 'Aluin',
#   'last_name': 'Maha',
#   'email': 'amaha20@devhub.com',
#   'gender': 'Male',
#   'ip_address': '36.44.173.15'},
#  {'id': 74,
#   'first_name': 'Yardley',
#   'last_name': 'Hughf',
#   'email': 'yhughf21@wisc.edu',
#   'gender': 'Male',
#   'ip_address': '89.156.18.100'},
#  {'id': 75,
#   'first_name': 'Francene',
#   'last_name': 'Davoren',
#   'email': 'fdavoren22@hibu.com',
#   'gender': 'Genderqueer',
#   'ip_address': '154.57.252.31'},
#  {'id': 76,
#   'first_name': 'Alfreda',
#   'last_name': 'Curwood',
#   'email': 'acurwood23@alibaba.com',
#   'gender': 'Female',
#   'ip_address': '248.199.172.36'},
#  {'id': 77,
#   'first_name': 'Laurence',
#   'last_name': 'Ormistone',
#   'email': 'lormistone24@qq.com',
#   'gender': 'Male',
#   'ip_address': '184.6.171.155'},
#  {'id': 78,
#   'first_name': 'Pepita',
#   'last_name': 'Coveley',
#   'email': 'pcoveley25@blogger.com',
#   'gender': 'Female',
#   'ip_address': '2.239.79.116'},
#  {'id': 79,
#   'first_name': 'Nathanael',
#   'last_name': 'Shilston',
#   'email': 'nshilston26@reuters.com',
#   'gender': 'Male',
#   'ip_address': '162.3.247.217'},
#  {'id': 80,
#   'first_name': 'Timi',
#   'last_name': 'Geraldo',
#   'email': 'tgeraldo27@google.com.br',
#   'gender': 'Female',
#   'ip_address': '233.42.131.63'},
#  {'id': 81,
#   'first_name': 'Remy',
#   'last_name': 'Cavnor',
#   'email': 'rcavnor28@shareasale.com',
#   'gender': 'Female',
#   'ip_address': '77.178.171.133'},
#  {'id': 82,
#   'first_name': 'Shoshana',
#   'last_name': 'Gannicleff',
#   'email': 'sgannicleff29@sbwire.com',
#   'gender': 'Female',
#   'ip_address': '226.2.179.178'},
#  {'id': 83,
#   'first_name': 'Eugine',
#   'last_name': 'Maletratt',
#   'email': 'emaletratt2a@fc2.com',
#   'gender': 'Female',
#   'ip_address': '150.31.54.235'},
#  {'id': 84,
#   'first_name': 'Morse',
#   'last_name': 'Drinkall',
#   'email': 'mdrinkall2b@addthis.com',
#   'gender': 'Male',
#   'ip_address': '200.205.2.230'},
#  {'id': 85,
#   'first_name': 'Rex',
#   'last_name': 'Brimelow',
#   'email': 'rbrimelow2c@cdc.gov',
#   'gender': 'Male',
#   'ip_address': '59.211.24.56'},
#  {'id': 86,
#   'first_name': 'Arty',
#   'last_name': 'Wherton',
#   'email': 'awherton2d@tripadvisor.com',
#   'gender': 'Male',
#   'ip_address': '239.197.232.96'},
#  {'id': 87,
#   'first_name': 'Heather',
#   'last_name': 'Hammant',
#   'email': 'hhammant2e@cargocollective.com',
#   'gender': 'Female',
#   'ip_address': '114.19.69.173'},
#  {'id': 88,
#   'first_name': 'Kaspar',
#   'last_name': 'Litster',
#   'email': 'klitster2f@dedecms.com',
#   'gender': 'Male',
#   'ip_address': '193.58.100.4'},
#  {'id': 89,
#   'first_name': 'Tandi',
#   'last_name': 'Martusewicz',
#   'email': 'tmartusewicz2g@berkeley.edu',
#   'gender': 'Female',
#   'ip_address': '121.223.240.29'},
#  {'id': 90,
#   'first_name': 'Elsa',
#   'last_name': 'Coltart',
#   'email': 'ecoltart2h@businessweek.com',
#   'gender': 'Female',
#   'ip_address': '23.199.175.113'},
#  {'id': 91,
#   'first_name': 'Gwyn',
#   'last_name': 'Chalcraft',
#   'email': 'gchalcraft2i@usnews.com',
#   'gender': 'Female',
#   'ip_address': '170.204.142.253'},
#  {'id': 92,
#   'first_name': 'Blaire',
#   'last_name': 'Loddy',
#   'email': 'bloddy2j@utexas.edu',
#   'gender': 'Female',
#   'ip_address': '165.169.18.24'},
#  {'id': 93,
#   'first_name': 'Romeo',
#   'last_name': 'Siviter',
#   'email': 'rsiviter2k@typepad.com',
#   'gender': 'Male',
#   'ip_address': '175.34.117.251'},
#  {'id': 94,
#   'first_name': 'Anastasia',
#   'last_name': 'McBratney',
#   'email': 'amcbratney2l@instagram.com',
#   'gender': 'Female',
#   'ip_address': '168.237.224.36'},
#  {'id': 95,
#   'first_name': 'Elliott',
#   'last_name': 'Berardt',
#   'email': 'eberardt2m@altervista.org',
#   'gender': 'Genderfluid',
#   'ip_address': '20.165.74.107'},
#  {'id': 96,
#   'first_name': 'Urbanus',
#   'last_name': 'Robken',
#   'email': 'urobken2n@tinypic.com',
#   'gender': 'Agender',
#   'ip_address': '109.137.175.82'},
#  {'id': 97,
#   'first_name': 'Cal',
#   'last_name': 'Mordin',
#   'email': 'cmordin2o@goo.gl',
#   'gender': 'Agender',
#   'ip_address': '183.129.181.49'},
#  {'id': 98,
#   'first_name': 'Bentley',
#   'last_name': 'Hibbart',
#   'email': 'bhibbart2p@hao123.com',
#   'gender': 'Genderqueer',
#   'ip_address': '81.170.118.77'},
#  {'id': 99,
#   'first_name': 'Marielle',
#   'last_name': 'Cantera',
#   'email': 'mcantera2q@upenn.edu',
#   'gender': 'Female',
#   'ip_address': '173.72.231.60'},
#  {'id': 100,
#   'first_name': 'Adriano',
#   'last_name': 'Fiddian',
#   'email': 'afiddian2r@etsy.com',
#   'gender': 'Male',
#   'ip_address': '126.139.44.231'},
#  {'id': 101,
#   'first_name': 'Coriss',
#   'last_name': 'Neylon',
#   'email': 'cneylon2s@hao123.com',
#   'gender': 'Female',
#   'ip_address': '200.77.161.26'},
#  {'id': 102,
#   'first_name': 'Taylor',
#   'last_name': 'Ruter',
#   'email': 'truter2t@census.gov',
#   'gender': 'Male',
#   'ip_address': '44.103.39.17'},
#  {'id': 103,
#   'first_name': 'Donny',
#   'last_name': 'Wanley',
#   'email': 'dwanley2u@mtv.com',
#   'gender': 'Female',
#   'ip_address': '176.234.101.210'},
#  {'id': 104,
#   'first_name': 'Everett',
#   'last_name': 'Rogeron',
#   'email': 'erogeron2v@vinaora.com',
#   'gender': 'Male',
#   'ip_address': '227.138.124.137'},
#  {'id': 105,
#   'first_name': 'Traver',
#   'last_name': 'Gerson',
#   'email': 'tgerson2w@nature.com',
#   'gender': 'Male',
#   'ip_address': '89.115.226.181'},
#  {'id': 106,
#   'first_name': 'Teressa',
#   'last_name': 'Higounet',
#   'email': 'thigounet2x@g.co',
#   'gender': 'Agender',
#   'ip_address': '107.168.116.97'},
#  {'id': 107,
#   'first_name': 'Garvin',
#   'last_name': 'Robertsen',
#   'email': 'grobertsen2y@jugem.jp',
#   'gender': 'Male',
#   'ip_address': '236.227.163.240'},
#  {'id': 108,
#   'first_name': 'Brianna',
#   'last_name': 'Curle',
#   'email': 'bcurle2z@slideshare.net',
#   'gender': 'Female',
#   'ip_address': '239.220.24.199'},
#  {'id': 109,
#   'first_name': 'Herrick',
#   'last_name': 'Kock',
#   'email': 'hkock30@thetimes.co.uk',
#   'gender': 'Male',
#   'ip_address': '172.145.123.127'},
#  {'id': 110,
#   'first_name': 'Derby',
#   'last_name': 'Linbohm',
#   'email': 'dlinbohm31@ca.gov',
#   'gender': 'Male',
#   'ip_address': '174.186.187.116'},
#  {'id': 111,
#   'first_name': 'Esta',
#   'last_name': 'Place',
#   'email': 'eplace32@youtube.com',
#   'gender': 'Female',
#   'ip_address': '193.216.41.84'},
#  {'id': 112,
#   'first_name': 'Mavis',
#   'last_name': 'Swateridge',
#   'email': 'mswateridge33@mtv.com',
#   'gender': 'Female',
#   'ip_address': '47.25.196.168'},
#  {'id': 113,
#   'first_name': 'Sig',
#   'last_name': 'Cicculini',
#   'email': 'scicculini34@sciencedirect.com',
#   'gender': 'Male',
#   'ip_address': '200.48.254.142'},
#  {'id': 114,
#   'first_name': 'Gisele',
#   'last_name': 'Baggarley',
#   'email': 'gbaggarley35@sfgate.com',
#   'gender': 'Female',
#   'ip_address': '114.243.214.161'},
#  {'id': 115,
#   'first_name': 'Callida',
#   'last_name': 'Ghidini',
#   'email': 'cghidini36@people.com.cn',
#   'gender': 'Female',
#   'ip_address': '254.147.29.128'},
#  {'id': 116,
#   'first_name': 'Jolie',
#   'last_name': 'Castellucci',
#   'email': 'jcastellucci37@aol.com',
#   'gender': 'Female',
#   'ip_address': '171.252.55.29'},
#  {'id': 117,
#   'first_name': 'Wandis',
#   'last_name': 'Dickons',
#   'email': 'wdickons38@nhs.uk',
#   'gender': 'Female',
#   'ip_address': '45.61.98.166'},
#  {'id': 118,
#   'first_name': 'Kathy',
#   'last_name': 'Lorking',
#   'email': 'klorking39@statcounter.com',
#   'gender': 'Female',
#   'ip_address': '176.96.135.108'},
#  {'id': 119,
#   'first_name': 'Maurice',
#   'last_name': 'Phorsby',
#   'email': 'mphorsby3a@blogs.com',
#   'gender': 'Male',
#   'ip_address': '38.254.171.111'},
#  {'id': 120,
#   'first_name': 'Hymie',
#   'last_name': 'Cutbirth',
#   'email': 'hcutbirth3b@bravesites.com',
#   'gender': 'Male',
#   'ip_address': '226.247.3.162'},
#  {'id': 121,
#   'first_name': 'Kaleena',
#   'last_name': 'Mignot',
#   'email': 'kmignot3c@eventbrite.com',
#   'gender': 'Polygender',
#   'ip_address': '11.240.85.167'},
#  {'id': 122,
#   'first_name': 'Charmion',
#   'last_name': 'Schenkel',
#   'email': 'cschenkel3d@networksolutions.com',
#   'gender': 'Polygender',
#   'ip_address': '193.6.53.231'},
#  {'id': 123,
#   'first_name': 'Alvira',
#   'last_name': 'Puttan',
#   'email': 'aputtan3e@skype.com',
#   'gender': 'Female',
#   'ip_address': '216.157.220.151'},
#  {'id': 124,
#   'first_name': 'Loutitia',
#   'last_name': 'Durkin',
#   'email': 'ldurkin3f@usda.gov',
#   'gender': 'Female',
#   'ip_address': '88.110.182.229'},
#  {'id': 125,
#   'first_name': 'Mead',
#   'last_name': 'Coushe',
#   'email': 'mcoushe3g@moonfruit.com',
#   'gender': 'Male',
#   'ip_address': '220.223.111.251'},
#  {'id': 126,
#   'first_name': 'Guss',
#   'last_name': 'Kitcher',
#   'email': 'gkitcher3h@miitbeian.gov.cn',
#   'gender': 'Male',
#   'ip_address': '189.37.121.97'},
#  {'id': 127,
#   'first_name': 'Laureen',
#   'last_name': 'Donwell',
#   'email': 'ldonwell3i@jalbum.net',
#   'gender': 'Female',
#   'ip_address': '68.132.228.90'},
#  {'id': 128,
#   'first_name': 'Arnold',
#   'last_name': 'Dybald',
#   'email': 'adybald3j@washingtonpost.com',
#   'gender': 'Male',
#   'ip_address': '157.34.244.30'},
#  {'id': 129,
#   'first_name': 'Cynthy',
#   'last_name': 'Scrogges',
#   'email': 'cscrogges3k@nasa.gov',
#   'gender': 'Female',
#   'ip_address': '141.170.151.221'},
#  {'id': 130,
#   'first_name': 'Cinda',
#   'last_name': 'Pass',
#   'email': 'cpass3l@tumblr.com',
#   'gender': 'Bigender',
#   'ip_address': '98.107.235.29'},
#  {'id': 131,
#   'first_name': 'Charlena',
#   'last_name': 'Gypson',
#   'email': 'cgypson3m@samsung.com',
#   'gender': 'Female',
#   'ip_address': '59.164.153.144'},
#  {'id': 132,
#   'first_name': 'Joyann',
#   'last_name': 'Cotte',
#   'email': 'jcotte3n@walmart.com',
#   'gender': 'Female',
#   'ip_address': '72.186.70.143'},
#  {'id': 133,
#   'first_name': 'Seana',
#   'last_name': 'Tregunna',
#   'email': 'stregunna3o@bbc.co.uk',
#   'gender': 'Female',
#   'ip_address': '152.140.147.237'},
#  {'id': 134,
#   'first_name': 'Taryn',
#   'last_name': 'Node',
#   'email': 'tnode3p@ebay.co.uk',
#   'gender': 'Female',
#   'ip_address': '25.55.41.159'},
#  {'id': 135,
#   'first_name': 'Bonnibelle',
#   'last_name': 'Curnnok',
#   'email': 'bcurnnok3q@merriam-webster.com',
#   'gender': 'Female',
#   'ip_address': '134.209.130.176'},
#  {'id': 136,
#   'first_name': 'Dorie',
#   'last_name': 'Keniwell',
#   'email': 'dkeniwell3r@wordpress.org',
#   'gender': 'Polygender',
#   'ip_address': '25.34.101.123'},
#  {'id': 137,
#   'first_name': 'Berkly',
#   'last_name': 'Oats',
#   'email': 'boats3s@weebly.com',
#   'gender': 'Male',
#   'ip_address': '51.75.113.158'},
#  {'id': 138,
#   'first_name': 'Niven',
#   'last_name': 'Balloch',
#   'email': 'nballoch3t@cmu.edu',
#   'gender': 'Male',
#   'ip_address': '8.116.176.63'},
#  {'id': 139,
#   'first_name': 'Michal',
#   'last_name': 'Stambridge',
#   'email': 'mstambridge3u@miibeian.gov.cn',
#   'gender': 'Male',
#   'ip_address': '228.30.178.213'},
#  {'id': 140,
#   'first_name': 'Wendi',
#   'last_name': 'Lavin',
#   'email': 'wlavin3v@dmoz.org',
#   'gender': 'Female',
#   'ip_address': '94.128.150.31'},
#  {'id': 141,
#   'first_name': 'Franklin',
#   'last_name': 'MacIntyre',
#   'email': 'fmacintyre3w@hud.gov',
#   'gender': 'Male',
#   'ip_address': '245.171.1.153'},
#  {'id': 142,
#   'first_name': 'Morley',
#   'last_name': 'MacSwayde',
#   'email': 'mmacswayde3x@un.org',
#   'gender': 'Male',
#   'ip_address': '23.238.180.191'},
#  {'id': 143,
#   'first_name': 'Karmen',
#   'last_name': 'Gavrielly',
#   'email': 'kgavrielly3y@state.tx.us',
#   'gender': 'Female',
#   'ip_address': '138.116.125.232'},
#  {'id': 144,
#   'first_name': 'Mavis',
#   'last_name': 'Berggren',
#   'email': 'mberggren3z@berkeley.edu',
#   'gender': 'Female',
#   'ip_address': '180.223.225.140'},
#  {'id': 145,
#   'first_name': 'Wendell',
#   'last_name': 'Waight',
#   'email': 'wwaight40@samsung.com',
#   'gender': 'Male',
#   'ip_address': '70.113.164.246'},
#  {'id': 146,
#   'first_name': 'Anders',
#   'last_name': 'Leake',
#   'email': 'aleake41@hud.gov',
#   'gender': 'Male',
#   'ip_address': '206.52.5.42'},
#  {'id': 147,
#   'first_name': 'Cyndy',
#   'last_name': 'Dartnell',
#   'email': 'cdartnell42@ed.gov',
#   'gender': 'Female',
#   'ip_address': '29.180.40.41'},
#  {'id': 148,
#   'first_name': 'Aeriel',
#   'last_name': 'Lowery',
#   'email': 'alowery43@flavors.me',
#   'gender': 'Female',
#   'ip_address': '231.64.28.138'},
#  {'id': 149,
#   'first_name': 'Harley',
#   'last_name': 'Cready',
#   'email': 'hcready44@ebay.co.uk',
#   'gender': 'Polygender',
#   'ip_address': '205.196.30.23'},
#  {'id': 150,
#   'first_name': 'Willamina',
#   'last_name': 'Bickersteth',
#   'email': 'wbickersteth45@alibaba.com',
#   'gender': 'Female',
#   'ip_address': '83.233.4.124'},
#  {'id': 151,
#   'first_name': 'Hugibert',
#   'last_name': 'Hansel',
#   'email': 'hhansel46@dmoz.org',
#   'gender': 'Male',
#   'ip_address': '4.95.172.123'},
#  {'id': 152,
#   'first_name': 'Tobe',
#   'last_name': 'Coning',
#   'email': 'tconing47@ftc.gov',
#   'gender': 'Non-binary',
#   'ip_address': '173.87.232.104'},
#  {'id': 153,
#   'first_name': 'Saxon',
#   'last_name': 'Carty',
#   'email': 'scarty48@craigslist.org',
#   'gender': 'Male',
#   'ip_address': '189.21.228.85'},
#  {'id': 154,
#   'first_name': 'Shannon',
#   'last_name': 'Sherry',
#   'email': 'ssherry49@umich.edu',
#   'gender': 'Male',
#   'ip_address': '198.240.249.189'},
#  {'id': 155,
#   'first_name': 'Carny',
#   'last_name': 'Barnewelle',
#   'email': 'cbarnewelle4a@squidoo.com',
#   'gender': 'Male',
#   'ip_address': '14.208.72.87'},
#  {'id': 156,
#   'first_name': 'Jolynn',
#   'last_name': 'Blinman',
#   'email': 'jblinman4b@booking.com',
#   'gender': 'Non-binary',
#   'ip_address': '245.239.87.56'},
#  {'id': 157,
#   'first_name': 'Klemens',
#   'last_name': 'Canas',
#   'email': 'kcanas4c@meetup.com',
#   'gender': 'Male',
#   'ip_address': '255.102.17.37'},
#  {'id': 158,
#   'first_name': 'Anthiathia',
#   'last_name': 'Bulfit',
#   'email': 'abulfit4d@symantec.com',
#   'gender': 'Female',
#   'ip_address': '142.134.53.46'},
#  {'id': 159,
#   'first_name': 'Wenonah',
#   'last_name': 'Wadman',
#   'email': 'wwadman4e@furl.net',
#   'gender': 'Female',
#   'ip_address': '139.145.198.121'},
#  {'id': 160,
#   'first_name': 'Lurleen',
#   'last_name': 'Eyckel',
#   'email': 'leyckel4f@paginegialle.it',
#   'gender': 'Female',
#   'ip_address': '2.2.32.20'},
#  {'id': 161,
#   'first_name': 'Normy',
#   'last_name': 'Cordelle',
#   'email': 'ncordelle4g@nih.gov',
#   'gender': 'Male',
#   'ip_address': '210.198.83.236'},
#  {'id': 162,
#   'first_name': 'Waylan',
#   'last_name': 'Jensen',
#   'email': 'wjensen4h@harvard.edu',
#   'gender': 'Male',
#   'ip_address': '60.250.24.241'},
#  {'id': 163,
#   'first_name': 'Glenna',
#   'last_name': 'Demer',
#   'email': 'gdemer4i@tmall.com',
#   'gender': 'Female',
#   'ip_address': '225.213.117.230'},
#  {'id': 164,
#   'first_name': 'Batholomew',
#   'last_name': 'Nickoles',
#   'email': 'bnickoles4j@symantec.com',
#   'gender': 'Male',
#   'ip_address': '76.183.119.58'},
#  {'id': 165,
#   'first_name': 'Kali',
#   'last_name': 'Gerran',
#   'email': 'kgerran4k@nps.gov',
#   'gender': 'Female',
#   'ip_address': '161.99.49.109'},
#  {'id': 166,
#   'first_name': 'Davide',
#   'last_name': 'Conerding',
#   'email': 'dconerding4l@simplemachines.org',
#   'gender': 'Male',
#   'ip_address': '108.192.236.58'},
#  {'id': 167,
#   'first_name': 'Becka',
#   'last_name': 'Lawrenceson',
#   'email': 'blawrenceson4m@blinklist.com',
#   'gender': 'Female',
#   'ip_address': '48.242.43.120'},
#  {'id': 168,
#   'first_name': 'Coraline',
#   'last_name': 'Dicks',
#   'email': 'cdicks4n@merriam-webster.com',
#   'gender': 'Female',
#   'ip_address': '98.79.75.239'},
#  {'id': 169,
#   'first_name': 'Aeriel',
#   'last_name': 'Pieracci',
#   'email': 'apieracci4o@tinyurl.com',
#   'gender': 'Female',
#   'ip_address': '195.229.91.181'},
#  {'id': 170,
#   'first_name': 'Rosene',
#   'last_name': 'Meriot',
#   'email': 'rmeriot4p@alibaba.com',
#   'gender': 'Female',
#   'ip_address': '206.101.77.227'},
#  {'id': 171,
#   'first_name': 'Duane',
#   'last_name': "D'Ambrosio",
#   'email': 'ddambrosio4q@rambler.ru',
#   'gender': 'Male',
#   'ip_address': '140.190.240.105'},
#  {'id': 172,
#   'first_name': 'Junina',
#   'last_name': 'Sutliff',
#   'email': 'jsutliff4r@accuweather.com',
#   'gender': 'Female',
#   'ip_address': '231.55.23.28'},
#  {'id': 173,
#   'first_name': 'Iolanthe',
#   'last_name': 'McKeefry',
#   'email': 'imckeefry4s@reverbnation.com',
#   'gender': 'Bigender',
#   'ip_address': '246.206.219.129'},
#  {'id': 174,
#   'first_name': 'Denna',
#   'last_name': 'Pidgin',
#   'email': 'dpidgin4t@alibaba.com',
#   'gender': 'Female',
#   'ip_address': '211.193.110.101'},
#  {'id': 175,
#   'first_name': 'Seana',
#   'last_name': 'Benbrick',
#   'email': 'sbenbrick4u@wisc.edu',
#   'gender': 'Female',
#   'ip_address': '39.158.27.246'},
#  {'id': 176,
#   'first_name': 'Karl',
#   'last_name': 'Willcott',
#   'email': 'kwillcott4v@umich.edu',
#   'gender': 'Bigender',
#   'ip_address': '130.172.106.100'},
#  {'id': 177,
#   'first_name': 'Piotr',
#   'last_name': 'Meadmore',
#   'email': 'pmeadmore4w@hexun.com',
#   'gender': 'Male',
#   'ip_address': '209.147.95.250'},
#  {'id': 178,
#   'first_name': 'Rozelle',
#   'last_name': 'Malkinson',
#   'email': 'rmalkinson4x@webnode.com',
#   'gender': 'Female',
#   'ip_address': '183.58.91.5'},
#  {'id': 179,
#   'first_name': 'Olia',
#   'last_name': 'Breydin',
#   'email': 'obreydin4y@intel.com',
#   'gender': 'Female',
#   'ip_address': '109.168.88.48'},
#  {'id': 180,
#   'first_name': 'Carlie',
#   'last_name': 'Braine',
#   'email': 'cbraine4z@facebook.com',
#   'gender': 'Male',
#   'ip_address': '39.214.67.130'},
#  {'id': 181,
#   'first_name': 'May',
#   'last_name': 'Rennard',
#   'email': 'mrennard50@weather.com',
#   'gender': 'Female',
#   'ip_address': '167.121.158.3'},
#  {'id': 182,
#   'first_name': 'Katherine',
#   'last_name': 'Marmyon',
#   'email': 'kmarmyon51@baidu.com',
#   'gender': 'Female',
#   'ip_address': '68.229.107.142'},
#  {'id': 183,
#   'first_name': 'Kissee',
#   'last_name': 'Meaden',
#   'email': 'kmeaden52@sogou.com',
#   'gender': 'Female',
#   'ip_address': '190.189.174.31'},
#  {'id': 184,
#   'first_name': 'Consuela',
#   'last_name': 'Friedank',
#   'email': 'cfriedank53@miitbeian.gov.cn',
#   'gender': 'Female',
#   'ip_address': '174.199.230.32'},
#  {'id': 185,
#   'first_name': 'Nathaniel',
#   'last_name': 'McKinty',
#   'email': 'nmckinty54@macromedia.com',
#   'gender': 'Male',
#   'ip_address': '245.23.95.163'},
#  {'id': 186,
#   'first_name': 'Wynnie',
#   'last_name': 'Lowdiane',
#   'email': 'wlowdiane55@harvard.edu',
#   'gender': 'Female',
#   'ip_address': '247.165.87.4'},
#  {'id': 187,
#   'first_name': 'Timothee',
#   'last_name': 'Beves',
#   'email': 'tbeves56@domainmarket.com',
#   'gender': 'Male',
#   'ip_address': '167.170.143.132'},
#  {'id': 188,
#   'first_name': 'Wake',
#   'last_name': 'Peaden',
#   'email': 'wpeaden57@usatoday.com',
#   'gender': 'Male',
#   'ip_address': '160.211.187.141'},
#  {'id': 189,
#   'first_name': 'Ree',
#   'last_name': 'Casewell',
#   'email': 'rcasewell58@discuz.net',
#   'gender': 'Female',
#   'ip_address': '239.47.20.129'},
#  {'id': 190,
#   'first_name': 'Georas',
#   'last_name': 'Bonafant',
#   'email': 'gbonafant59@printfriendly.com',
#   'gender': 'Male',
#   'ip_address': '30.5.8.104'},
#  {'id': 191,
#   'first_name': 'Matty',
#   'last_name': 'Tsarovic',
#   'email': 'mtsarovic5a@disqus.com',
#   'gender': 'Female',
#   'ip_address': '97.249.174.105'},
#  {'id': 192,
#   'first_name': 'Shanda',
#   'last_name': 'Valens-Smith',
#   'email': 'svalenssmith5b@yellowbook.com',
#   'gender': 'Female',
#   'ip_address': '148.103.31.50'},
#  {'id': 193,
#   'first_name': 'Curran',
#   'last_name': 'Callander',
#   'email': 'ccallander5c@histats.com',
#   'gender': 'Male',
#   'ip_address': '205.132.111.73'},
#  {'id': 194,
#   'first_name': 'Thibaud',
#   'last_name': 'Snoddy',
#   'email': 'tsnoddy5d@zimbio.com',
#   'gender': 'Male',
#   'ip_address': '242.120.45.169'},
#  {'id': 195,
#   'first_name': 'Ilka',
#   'last_name': 'Bebis',
#   'email': 'ibebis5e@amazon.com',
#   'gender': 'Female',
#   'ip_address': '160.49.159.92'},
#  {'id': 196,
#   'first_name': 'Daveen',
#   'last_name': 'Karpmann',
#   'email': 'dkarpmann5f@discovery.com',
#   'gender': 'Female',
#   'ip_address': '145.247.40.190'},
#  {'id': 197,
#   'first_name': 'Catha',
#   'last_name': 'Rafter',
#   'email': 'crafter5g@mediafire.com',
#   'gender': 'Female',
#   'ip_address': '37.197.82.35'},
#  {'id': 198,
#   'first_name': 'Whit',
#   'last_name': 'Anthona',
#   'email': 'wanthona5h@digg.com',
#   'gender': 'Male',
#   'ip_address': '247.132.157.228'},
#  {'id': 199,
#   'first_name': 'Martha',
#   'last_name': 'Bowskill',
#   'email': 'mbowskill5i@naver.com',
#   'gender': 'Female',
#   'ip_address': '56.86.164.10'},
#  {'id': 200,
#   'first_name': 'Selina',
#   'last_name': 'Natwick',
#   'email': 'snatwick5j@simplemachines.org',
#   'gender': 'Female',
#   'ip_address': '168.210.200.142'},
#  {'id': 201,
#   'first_name': 'Marieann',
#   'last_name': 'Stote',
#   'email': 'mstote5k@bbc.co.uk',
#   'gender': 'Female',
#   'ip_address': '21.201.58.71'},
#  {'id': 202,
#   'first_name': 'Falkner',
#   'last_name': 'Kain',
#   'email': 'fkain5l@goodreads.com',
#   'gender': 'Male',
#   'ip_address': '254.115.213.19'},
#  {'id': 203,
#   'first_name': 'Buffy',
#   'last_name': 'Chaves',
#   'email': 'bchaves5m@cmu.edu',
#   'gender': 'Female',
#   'ip_address': '24.152.171.198'},
#  {'id': 204,
#   'first_name': 'Aube',
#   'last_name': 'Doolan',
#   'email': 'adoolan5n@hibu.com',
#   'gender': 'Male',
#   'ip_address': '248.7.192.92'},
#  {'id': 205,
#   'first_name': 'Courtney',
#   'last_name': 'Roche',
#   'email': 'croche5o@shareasale.com',
#   'gender': 'Male',
#   'ip_address': '252.119.58.183'},
#  {'id': 206,
#   'first_name': 'Valina',
#   'last_name': 'Castellani',
#   'email': 'vcastellani5p@loc.gov',
#   'gender': 'Female',
#   'ip_address': '156.197.171.97'},
#  {'id': 207,
#   'first_name': 'Madeline',
#   'last_name': 'Bastick',
#   'email': 'mbastick5q@last.fm',
#   'gender': 'Female',
#   'ip_address': '17.233.78.67'},
#  {'id': 208,
#   'first_name': 'Karla',
#   'last_name': 'Cluatt',
#   'email': 'kcluatt5r@whitehouse.gov',
#   'gender': 'Female',
#   'ip_address': '126.1.138.255'},
#  {'id': 209,
#   'first_name': 'Mill',
#   'last_name': 'Andric',
#   'email': 'mandric5s@hostgator.com',
#   'gender': 'Male',
#   'ip_address': '170.153.63.190'},
#  {'id': 210,
#   'first_name': 'Jorge',
#   'last_name': 'Causnett',
#   'email': 'jcausnett5t@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '99.182.245.40'},
#  {'id': 211,
#   'first_name': 'Zarla',
#   'last_name': 'Klausewitz',
#   'email': 'zklausewitz5u@163.com',
#   'gender': 'Female',
#   'ip_address': '18.216.135.253'},
#  {'id': 212,
#   'first_name': 'Germayne',
#   'last_name': 'Penlington',
#   'email': 'gpenlington5v@posterous.com',
#   'gender': 'Male',
#   'ip_address': '128.234.7.39'},
#  {'id': 213,
#   'first_name': 'Malia',
#   'last_name': 'Flahive',
#   'email': 'mflahive5w@nymag.com',
#   'gender': 'Female',
#   'ip_address': '67.7.130.155'},
#  {'id': 214,
#   'first_name': 'Tracy',
#   'last_name': 'McLaggan',
#   'email': 'tmclaggan5x@wordpress.org',
#   'gender': 'Genderqueer',
#   'ip_address': '149.109.125.55'},
#  {'id': 215,
#   'first_name': 'Malina',
#   'last_name': 'Beau',
#   'email': 'mbeau5y@marriott.com',
#   'gender': 'Female',
#   'ip_address': '155.101.4.239'},
#  {'id': 216,
#   'first_name': 'Turner',
#   'last_name': 'Featherbie',
#   'email': 'tfeatherbie5z@issuu.com',
#   'gender': 'Male',
#   'ip_address': '178.164.82.196'},
#  {'id': 217,
#   'first_name': 'Uri',
#   'last_name': 'Keslake',
#   'email': 'ukeslake60@quantcast.com',
#   'gender': 'Male',
#   'ip_address': '215.2.208.153'},
#  {'id': 218,
#   'first_name': 'Clerissa',
#   'last_name': 'Kendall',
#   'email': 'ckendall61@harvard.edu',
#   'gender': 'Female',
#   'ip_address': '88.212.217.204'},
#  {'id': 219,
#   'first_name': 'Tyler',
#   'last_name': 'Micco',
#   'email': 'tmicco62@chron.com',
#   'gender': 'Male',
#   'ip_address': '7.241.209.41'},
#  {'id': 220,
#   'first_name': 'Dewain',
#   'last_name': 'Mossdale',
#   'email': 'dmossdale63@google.ru',
#   'gender': 'Male',
#   'ip_address': '164.224.225.145'},
#  {'id': 221,
#   'first_name': 'Natassia',
#   'last_name': 'Gligorijevic',
#   'email': 'ngligorijevic64@wufoo.com',
#   'gender': 'Female',
#   'ip_address': '106.249.112.63'},
#  {'id': 222,
#   'first_name': 'Riley',
#   'last_name': 'Rosenbush',
#   'email': 'rrosenbush65@bloomberg.com',
#   'gender': 'Male',
#   'ip_address': '23.85.153.194'},
#  {'id': 223,
#   'first_name': 'Delilah',
#   'last_name': 'Garaway',
#   'email': 'dgaraway66@nyu.edu',
#   'gender': 'Female',
#   'ip_address': '244.211.31.34'},
#  {'id': 224,
#   'first_name': 'Corrie',
#   'last_name': 'Eldershaw',
#   'email': 'celdershaw67@ox.ac.uk',
#   'gender': 'Female',
#   'ip_address': '122.54.240.80'},
#  {'id': 225,
#   'first_name': 'Anna',
#   'last_name': 'Trudgian',
#   'email': 'atrudgian68@independent.co.uk',
#   'gender': 'Female',
#   'ip_address': '124.180.176.36'},
#  {'id': 226,
#   'first_name': 'Clarinda',
#   'last_name': 'Stather',
#   'email': 'cstather69@pen.io',
#   'gender': 'Female',
#   'ip_address': '149.93.176.69'},
#  {'id': 227,
#   'first_name': 'Judy',
#   'last_name': 'Croy',
#   'email': 'jcroy6a@twitpic.com',
#   'gender': 'Female',
#   'ip_address': '86.10.239.241'},
#  {'id': 228,
#   'first_name': 'Berenice',
#   'last_name': 'Bunch',
#   'email': 'bbunch6b@spiegel.de',
#   'gender': 'Female',
#   'ip_address': '85.212.109.55'},
#  {'id': 229,
#   'first_name': 'Will',
#   'last_name': 'Allner',
#   'email': 'wallner6c@goo.ne.jp',
#   'gender': 'Male',
#   'ip_address': '215.19.33.183'},
#  {'id': 230,
#   'first_name': 'Moritz',
#   'last_name': 'Troak',
#   'email': 'mtroak6d@java.com',
#   'gender': 'Male',
#   'ip_address': '161.127.18.77'},
#  {'id': 231,
#   'first_name': 'Garnette',
#   'last_name': 'Watling',
#   'email': 'gwatling6e@example.com',
#   'gender': 'Female',
#   'ip_address': '86.151.42.169'},
#  {'id': 232,
#   'first_name': 'Flory',
#   'last_name': 'Evans',
#   'email': 'fevans6f@tinypic.com',
#   'gender': 'Female',
#   'ip_address': '33.240.95.172'},
#  {'id': 233,
#   'first_name': 'Elinore',
#   'last_name': 'Ruck',
#   'email': 'eruck6g@dell.com',
#   'gender': 'Female',
#   'ip_address': '58.118.120.102'},
#  {'id': 234,
#   'first_name': 'Manya',
#   'last_name': 'Beauchamp',
#   'email': 'mbeauchamp6h@g.co',
#   'gender': 'Female',
#   'ip_address': '31.81.251.117'},
#  {'id': 235,
#   'first_name': 'Candace',
#   'last_name': 'Showl',
#   'email': 'cshowl6i@xinhuanet.com',
#   'gender': 'Female',
#   'ip_address': '220.20.220.49'},
#  {'id': 236,
#   'first_name': 'Tilda',
#   'last_name': 'Blench',
#   'email': 'tblench6j@epa.gov',
#   'gender': 'Female',
#   'ip_address': '161.242.105.192'},
#  {'id': 237,
#   'first_name': 'Denny',
#   'last_name': 'Keeton',
#   'email': 'dkeeton6k@webs.com',
#   'gender': 'Male',
#   'ip_address': '53.188.224.167'},
#  {'id': 238,
#   'first_name': 'Cher',
#   'last_name': 'Sisse',
#   'email': 'csisse6l@usgs.gov',
#   'gender': 'Female',
#   'ip_address': '58.220.119.225'},
#  {'id': 239,
#   'first_name': 'Nicki',
#   'last_name': 'Braidley',
#   'email': 'nbraidley6m@si.edu',
#   'gender': 'Female',
#   'ip_address': '143.247.28.100'},
#  {'id': 240,
#   'first_name': 'Lilias',
#   'last_name': 'Hurne',
#   'email': 'lhurne6n@apache.org',
#   'gender': 'Female',
#   'ip_address': '23.245.234.190'},
#  {'id': 241,
#   'first_name': 'Dolores',
#   'last_name': 'Manhare',
#   'email': 'dmanhare6o@mtv.com',
#   'gender': 'Bigender',
#   'ip_address': '191.45.46.163'},
#  {'id': 242,
#   'first_name': 'Miner',
#   'last_name': 'MacPhaden',
#   'email': 'mmacphaden6p@posterous.com',
#   'gender': 'Male',
#   'ip_address': '0.225.192.123'},
#  {'id': 243,
#   'first_name': 'Stephenie',
#   'last_name': 'Vickress',
#   'email': 'svickress6q@cafepress.com',
#   'gender': 'Female',
#   'ip_address': '24.44.87.192'},
#  {'id': 244,
#   'first_name': 'Nelia',
#   'last_name': 'Whitehall',
#   'email': 'nwhitehall6r@unicef.org',
#   'gender': 'Female',
#   'ip_address': '69.188.159.123'},
#  {'id': 245,
#   'first_name': 'Patience',
#   'last_name': 'Oddboy',
#   'email': 'poddboy6s@uiuc.edu',
#   'gender': 'Female',
#   'ip_address': '236.245.195.212'},
#  {'id': 246,
#   'first_name': 'Mary',
#   'last_name': 'Blaw',
#   'email': 'mblaw6t@a8.net',
#   'gender': 'Female',
#   'ip_address': '136.151.133.244'},
#  {'id': 247,
#   'first_name': 'Bartholomew',
#   'last_name': 'Durtnel',
#   'email': 'bdurtnel6u@mozilla.com',
#   'gender': 'Male',
#   'ip_address': '100.117.197.85'},
#  {'id': 248,
#   'first_name': 'Judi',
#   'last_name': 'Dunbobin',
#   'email': 'jdunbobin6v@bbc.co.uk',
#   'gender': 'Female',
#   'ip_address': '15.238.216.42'},
#  {'id': 249,
#   'first_name': 'Maegan',
#   'last_name': 'Inker',
#   'email': 'minker6w@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '124.132.214.71'},
#  {'id': 250,
#   'first_name': 'Berky',
#   'last_name': 'Lage',
#   'email': 'blage6x@myspace.com',
#   'gender': 'Male',
#   'ip_address': '108.30.45.48'},
#  {'id': 251,
#   'first_name': 'Guss',
#   'last_name': 'Robey',
#   'email': 'grobey6y@whitehouse.gov',
#   'gender': 'Male',
#   'ip_address': '215.41.189.86'},
#  {'id': 252,
#   'first_name': 'Gaston',
#   'last_name': 'Moine',
#   'email': 'gmoine6z@weebly.com',
#   'gender': 'Male',
#   'ip_address': '210.68.46.229'},
#  {'id': 253,
#   'first_name': 'Natty',
#   'last_name': 'Tassell',
#   'email': 'ntassell70@phpbb.com',
#   'gender': 'Female',
#   'ip_address': '16.18.233.166'},
#  {'id': 254,
#   'first_name': 'Corny',
#   'last_name': 'Huggon',
#   'email': 'chuggon71@cbsnews.com',
#   'gender': 'Female',
#   'ip_address': '230.85.163.196'},
#  {'id': 255,
#   'first_name': 'Isabelle',
#   'last_name': 'Hrinishin',
#   'email': 'ihrinishin72@nih.gov',
#   'gender': 'Female',
#   'ip_address': '11.165.87.226'},
#  {'id': 256,
#   'first_name': 'Simon',
#   'last_name': 'Brake',
#   'email': 'sbrake73@google.co.uk',
#   'gender': 'Male',
#   'ip_address': '42.248.171.87'},
#  {'id': 257,
#   'first_name': 'Manya',
#   'last_name': 'Castagna',
#   'email': 'mcastagna74@youtu.be',
#   'gender': 'Female',
#   'ip_address': '115.83.184.217'},
#  {'id': 258,
#   'first_name': 'Fred',
#   'last_name': 'Ranyell',
#   'email': 'franyell75@baidu.com',
#   'gender': 'Male',
#   'ip_address': '190.133.24.52'},
#  {'id': 259,
#   'first_name': 'Beverie',
#   'last_name': 'Snelson',
#   'email': 'bsnelson76@prweb.com',
#   'gender': 'Female',
#   'ip_address': '154.108.225.163'},
#  {'id': 260,
#   'first_name': 'Lilly',
#   'last_name': 'Guise',
#   'email': 'lguise77@zdnet.com',
#   'gender': 'Female',
#   'ip_address': '114.10.125.183'},
#  {'id': 261,
#   'first_name': 'Chase',
#   'last_name': 'Eastbrook',
#   'email': 'ceastbrook78@apache.org',
#   'gender': 'Male',
#   'ip_address': '213.127.16.47'},
#  {'id': 262,
#   'first_name': 'Carolina',
#   'last_name': 'Rosengarten',
#   'email': 'crosengarten79@chron.com',
#   'gender': 'Female',
#   'ip_address': '208.118.90.174'},
#  {'id': 263,
#   'first_name': 'Pattie',
#   'last_name': 'Bearsmore',
#   'email': 'pbearsmore7a@salon.com',
#   'gender': 'Polygender',
#   'ip_address': '200.211.5.147'},
#  {'id': 264,
#   'first_name': 'Nickolaus',
#   'last_name': 'Collcott',
#   'email': 'ncollcott7b@cbslocal.com',
#   'gender': 'Male',
#   'ip_address': '237.174.228.61'},
#  {'id': 265,
#   'first_name': 'Roz',
#   'last_name': 'Wynter',
#   'email': 'rwynter7c@drupal.org',
#   'gender': 'Female',
#   'ip_address': '194.27.235.85'},
#  {'id': 266,
#   'first_name': 'Arliene',
#   'last_name': 'Gowers',
#   'email': 'agowers7d@arizona.edu',
#   'gender': 'Female',
#   'ip_address': '236.189.150.43'},
#  {'id': 267,
#   'first_name': 'Vinson',
#   'last_name': 'Newby',
#   'email': 'vnewby7e@umn.edu',
#   'gender': 'Male',
#   'ip_address': '6.117.185.191'},
#  {'id': 268,
#   'first_name': 'Lewes',
#   'last_name': 'Struan',
#   'email': 'lstruan7f@virginia.edu',
#   'gender': 'Male',
#   'ip_address': '145.139.41.231'},
#  {'id': 269,
#   'first_name': 'Geoffrey',
#   'last_name': 'Gyurkovics',
#   'email': 'ggyurkovics7g@behance.net',
#   'gender': 'Male',
#   'ip_address': '51.226.2.169'},
#  {'id': 270,
#   'first_name': 'Graehme',
#   'last_name': 'Gun',
#   'email': 'ggun7h@sfgate.com',
#   'gender': 'Male',
#   'ip_address': '198.32.119.0'},
#  {'id': 271,
#   'first_name': 'Hilly',
#   'last_name': 'Yexley',
#   'email': 'hyexley7i@goo.gl',
#   'gender': 'Male',
#   'ip_address': '83.125.163.40'},
#  {'id': 272,
#   'first_name': 'Cos',
#   'last_name': 'Lindblom',
#   'email': 'clindblom7j@bravesites.com',
#   'gender': 'Bigender',
#   'ip_address': '203.42.159.26'},
#  {'id': 273,
#   'first_name': 'Bernette',
#   'last_name': 'Sighart',
#   'email': 'bsighart7k@miibeian.gov.cn',
#   'gender': 'Female',
#   'ip_address': '66.79.227.175'},
#  {'id': 274,
#   'first_name': 'Vinny',
#   'last_name': 'Benit',
#   'email': 'vbenit7l@redcross.org',
#   'gender': 'Male',
#   'ip_address': '158.117.130.223'},
#  {'id': 275,
#   'first_name': 'Roosevelt',
#   'last_name': 'Rosa',
#   'email': 'rrosa7m@weebly.com',
#   'gender': 'Male',
#   'ip_address': '245.249.119.169'},
#  {'id': 276,
#   'first_name': 'Lucas',
#   'last_name': 'Emerine',
#   'email': 'lemerine7n@stanford.edu',
#   'gender': 'Male',
#   'ip_address': '188.68.248.97'},
#  {'id': 277,
#   'first_name': 'Nicole',
#   'last_name': 'Beacock',
#   'email': 'nbeacock7o@dmoz.org',
#   'gender': 'Female',
#   'ip_address': '143.197.196.166'},
#  {'id': 278,
#   'first_name': 'Gavrielle',
#   'last_name': 'Adne',
#   'email': 'gadne7p@cpanel.net',
#   'gender': 'Female',
#   'ip_address': '251.133.66.7'},
#  {'id': 279,
#   'first_name': 'Nobe',
#   'last_name': 'Dammarell',
#   'email': 'ndammarell7q@ox.ac.uk',
#   'gender': 'Male',
#   'ip_address': '83.111.186.241'},
#  {'id': 280,
#   'first_name': 'Malissa',
#   'last_name': 'Kemster',
#   'email': 'mkemster7r@blogtalkradio.com',
#   'gender': 'Female',
#   'ip_address': '27.158.244.181'},
#  {'id': 281,
#   'first_name': 'Carina',
#   'last_name': 'Scarrott',
#   'email': 'cscarrott7s@dion.ne.jp',
#   'gender': 'Female',
#   'ip_address': '178.217.212.85'},
#  {'id': 282,
#   'first_name': 'Wainwright',
#   'last_name': 'Escale',
#   'email': 'wescale7t@dailymotion.com',
#   'gender': 'Polygender',
#   'ip_address': '60.65.225.192'},
#  {'id': 283,
#   'first_name': 'Solly',
#   'last_name': 'Lapidus',
#   'email': 'slapidus7u@dion.ne.jp',
#   'gender': 'Male',
#   'ip_address': '53.13.230.111'},
#  {'id': 284,
#   'first_name': 'Rafi',
#   'last_name': 'Beavington',
#   'email': 'rbeavington7v@timesonline.co.uk',
#   'gender': 'Male',
#   'ip_address': '222.151.158.104'},
#  {'id': 285,
#   'first_name': 'Mehetabel',
#   'last_name': 'Feather',
#   'email': 'mfeather7w@state.tx.us',
#   'gender': 'Female',
#   'ip_address': '39.92.181.4'},
#  {'id': 286,
#   'first_name': 'Joeann',
#   'last_name': 'Kuna',
#   'email': 'jkuna7x@theatlantic.com',
#   'gender': 'Female',
#   'ip_address': '73.63.220.6'},
#  {'id': 287,
#   'first_name': 'Kerwin',
#   'last_name': 'Searl',
#   'email': 'ksearl7y@desdev.cn',
#   'gender': 'Male',
#   'ip_address': '239.213.39.173'},
#  {'id': 288,
#   'first_name': 'Alexandros',
#   'last_name': 'Sanson',
#   'email': 'asanson7z@usa.gov',
#   'gender': 'Genderqueer',
#   'ip_address': '205.16.200.215'},
#  {'id': 289,
#   'first_name': 'Brody',
#   'last_name': 'Faires',
#   'email': 'bfaires80@angelfire.com',
#   'gender': 'Male',
#   'ip_address': '129.211.172.23'},
#  {'id': 290,
#   'first_name': 'Monica',
#   'last_name': 'Paddon',
#   'email': 'mpaddon81@ed.gov',
#   'gender': 'Female',
#   'ip_address': '11.226.115.146'},
#  {'id': 291,
#   'first_name': 'Trixie',
#   'last_name': 'Storrah',
#   'email': 'tstorrah82@icq.com',
#   'gender': 'Female',
#   'ip_address': '123.124.173.164'},
#  {'id': 292,
#   'first_name': 'Henrik',
#   'last_name': 'Aery',
#   'email': 'haery83@who.int',
#   'gender': 'Male',
#   'ip_address': '50.113.36.60'},
#  {'id': 293,
#   'first_name': 'Rhett',
#   'last_name': 'Mussared',
#   'email': 'rmussared84@google.co.uk',
#   'gender': 'Male',
#   'ip_address': '6.107.195.252'},
#  {'id': 294,
#   'first_name': 'Isobel',
#   'last_name': 'Brammall',
#   'email': 'ibrammall85@sbwire.com',
#   'gender': 'Female',
#   'ip_address': '208.105.72.108'},
#  {'id': 295,
#   'first_name': 'Wilhelm',
#   'last_name': 'Shatliffe',
#   'email': 'wshatliffe86@sakura.ne.jp',
#   'gender': 'Male',
#   'ip_address': '230.237.12.98'},
#  {'id': 296,
#   'first_name': 'Caryl',
#   'last_name': 'Teodorski',
#   'email': 'cteodorski87@indiatimes.com',
#   'gender': 'Genderfluid',
#   'ip_address': '16.148.89.83'},
#  {'id': 297,
#   'first_name': 'Roxanne',
#   'last_name': 'Wakeham',
#   'email': 'rwakeham88@google.com.au',
#   'gender': 'Female',
#   'ip_address': '68.13.251.192'},
#  {'id': 298,
#   'first_name': 'Antonin',
#   'last_name': 'Jellico',
#   'email': 'ajellico89@addtoany.com',
#   'gender': 'Male',
#   'ip_address': '22.4.54.129'},
#  {'id': 299,
#   'first_name': 'Darryl',
#   'last_name': 'Cereceres',
#   'email': 'dcereceres8a@angelfire.com',
#   'gender': 'Male',
#   'ip_address': '213.78.212.203'},
#  {'id': 300,
#   'first_name': 'Patti',
#   'last_name': 'Rao',
#   'email': 'prao8b@cdbaby.com',
#   'gender': 'Female',
#   'ip_address': '245.9.219.231'},
#  {'id': 301,
#   'first_name': 'Arte',
#   'last_name': 'Loudon',
#   'email': 'aloudon8c@dagondesign.com',
#   'gender': 'Male',
#   'ip_address': '92.177.163.168'},
#  {'id': 302,
#   'first_name': 'Hamlin',
#   'last_name': 'Barukh',
#   'email': 'hbarukh8d@amazonaws.com',
#   'gender': 'Male',
#   'ip_address': '244.153.6.161'},
#  {'id': 303,
#   'first_name': 'Odelinda',
#   'last_name': 'Punter',
#   'email': 'opunter8e@cornell.edu',
#   'gender': 'Female',
#   'ip_address': '99.5.81.218'},
#  {'id': 304,
#   'first_name': 'Joshuah',
#   'last_name': 'Merman',
#   'email': 'jmerman8f@wordpress.org',
#   'gender': 'Male',
#   'ip_address': '216.168.192.141'},
#  {'id': 305,
#   'first_name': 'Lothaire',
#   'last_name': 'Bamlett',
#   'email': 'lbamlett8g@wsj.com',
#   'gender': 'Male',
#   'ip_address': '250.180.42.145'},
#  {'id': 306,
#   'first_name': 'Henri',
#   'last_name': 'Pinnigar',
#   'email': 'hpinnigar8h@nps.gov',
#   'gender': 'Male',
# ...
#   'gender': 'Polygender',
#   'ip_address': '165.21.77.38'},
#  {'id': 900,
#   'first_name': 'Madelyn',
#   'last_name': 'Salandino',
#   'email': 'msalandinooz@xrea.com',
#   'gender': 'Female',
#   'ip_address': '111.81.92.206'},
#  {'id': 901,
#   'first_name': 'Remy',
#   'last_name': 'Bein',
#   'email': 'rbeinp0@surveymonkey.com',
#   'gender': 'Female',
#   'ip_address': '179.198.206.69'},
#  {'id': 902,
#   'first_name': 'Carroll',
#   'last_name': 'Balbeck',
#   'email': 'cbalbeckp1@myspace.com',
#   'gender': 'Female',
#   'ip_address': '103.120.213.38'},
#  {'id': 903,
#   'first_name': 'Darsey',
#   'last_name': 'Breitler',
#   'email': 'dbreitlerp2@yelp.com',
#   'gender': 'Female',
#   'ip_address': '106.68.45.202'},
#  {'id': 904,
#   'first_name': 'Myrvyn',
#   'last_name': 'Burk',
#   'email': 'mburkp3@live.com',
#   'gender': 'Male',
#   'ip_address': '203.102.25.119'},
#  {'id': 905,
#   'first_name': 'Jerrome',
#   'last_name': 'Vaudrey',
#   'email': 'jvaudreyp4@npr.org',
#   'gender': 'Bigender',
#   'ip_address': '233.81.140.169'},
#  {'id': 906,
#   'first_name': 'Leif',
#   'last_name': 'Dell Casa',
#   'email': 'ldellcasap5@ucsd.edu',
#   'gender': 'Male',
#   'ip_address': '178.38.115.221'},
#  {'id': 907,
#   'first_name': 'Nora',
#   'last_name': 'Withey',
#   'email': 'nwitheyp6@mayoclinic.com',
#   'gender': 'Female',
#   'ip_address': '65.112.25.77'},
#  {'id': 908,
#   'first_name': 'Roman',
#   'last_name': 'Trillow',
#   'email': 'rtrillowp7@squarespace.com',
#   'gender': 'Male',
#   'ip_address': '25.149.48.149'},
#  {'id': 909,
#   'first_name': 'Carny',
#   'last_name': 'Phizaclea',
#   'email': 'cphizacleap8@wordpress.org',
#   'gender': 'Male',
#   'ip_address': '154.50.97.85'},
#  {'id': 910,
#   'first_name': 'Rhianna',
#   'last_name': 'Bayston',
#   'email': 'rbaystonp9@umich.edu',
#   'gender': 'Female',
#   'ip_address': '243.197.201.103'},
#  {'id': 911,
#   'first_name': 'Alphonse',
#   'last_name': 'Touson',
#   'email': 'atousonpa@google.ru',
#   'gender': 'Male',
#   'ip_address': '140.156.251.127'},
#  {'id': 912,
#   'first_name': 'Darrel',
#   'last_name': 'Udale',
#   'email': 'dudalepb@microsoft.com',
#   'gender': 'Male',
#   'ip_address': '142.18.222.136'},
#  {'id': 913,
#   'first_name': 'Brinna',
#   'last_name': 'Gres',
#   'email': 'bgrespc@delicious.com',
#   'gender': 'Female',
#   'ip_address': '250.120.142.85'},
#  {'id': 914,
#   'first_name': 'Malvin',
#   'last_name': 'Bramhill',
#   'email': 'mbramhillpd@businessweek.com',
#   'gender': 'Male',
#   'ip_address': '15.32.231.165'},
#  {'id': 915,
#   'first_name': 'Mignonne',
#   'last_name': 'Sorrell',
#   'email': 'msorrellpe@eventbrite.com',
#   'gender': 'Female',
#   'ip_address': '8.155.62.194'},
#  {'id': 916,
#   'first_name': 'Itch',
#   'last_name': 'Denyagin',
#   'email': 'idenyaginpf@discuz.net',
#   'gender': 'Male',
#   'ip_address': '40.162.4.78'},
#  {'id': 917,
#   'first_name': 'Rurik',
#   'last_name': 'Swindley',
#   'email': 'rswindleypg@i2i.jp',
#   'gender': 'Male',
#   'ip_address': '203.174.231.244'},
#  {'id': 918,
#   'first_name': 'Auguste',
#   'last_name': 'Burren',
#   'email': 'aburrenph@furl.net',
#   'gender': 'Female',
#   'ip_address': '198.233.42.92'},
#  {'id': 919,
#   'first_name': 'Willie',
#   'last_name': 'Bernat',
#   'email': 'wbernatpi@yahoo.com',
#   'gender': 'Male',
#   'ip_address': '194.69.220.66'},
#  {'id': 920,
#   'first_name': 'Mattheus',
#   'last_name': "O'Shevlin",
#   'email': 'moshevlinpj@mysql.com',
#   'gender': 'Male',
#   'ip_address': '209.157.130.197'},
#  {'id': 921,
#   'first_name': 'Mercedes',
#   'last_name': 'Hincks',
#   'email': 'mhinckspk@squidoo.com',
#   'gender': 'Agender',
#   'ip_address': '67.83.27.199'},
#  {'id': 922,
#   'first_name': 'Harmon',
#   'last_name': 'Plaschke',
#   'email': 'hplaschkepl@hatena.ne.jp',
#   'gender': 'Male',
#   'ip_address': '79.114.164.148'},
#  {'id': 923,
#   'first_name': 'Rina',
#   'last_name': 'Alan',
#   'email': 'ralanpm@bandcamp.com',
#   'gender': 'Female',
#   'ip_address': '253.254.79.18'},
#  {'id': 924,
#   'first_name': 'Essa',
#   'last_name': 'Nears',
#   'email': 'enearspn@vkontakte.ru',
#   'gender': 'Female',
#   'ip_address': '209.167.221.136'},
#  {'id': 925,
#   'first_name': 'Elspeth',
#   'last_name': 'Westmarland',
#   'email': 'ewestmarlandpo@ca.gov',
#   'gender': 'Female',
#   'ip_address': '230.252.99.247'},
#  {'id': 926,
#   'first_name': 'Annis',
#   'last_name': 'Fernely',
#   'email': 'afernelypp@mapquest.com',
#   'gender': 'Female',
#   'ip_address': '109.241.113.252'},
#  {'id': 927,
#   'first_name': 'Constancy',
#   'last_name': 'Pinck',
#   'email': 'cpinckpq@hibu.com',
#   'gender': 'Female',
#   'ip_address': '136.81.46.7'},
#  {'id': 928,
#   'first_name': 'Hadleigh',
#   'last_name': 'Faircliffe',
#   'email': 'hfaircliffepr@nbcnews.com',
#   'gender': 'Male',
#   'ip_address': '2.250.110.219'},
#  {'id': 929,
#   'first_name': 'Mack',
#   'last_name': 'Otterwell',
#   'email': 'motterwellps@e-recht24.de',
#   'gender': 'Male',
#   'ip_address': '179.103.86.240'},
#  {'id': 930,
#   'first_name': 'Bertie',
#   'last_name': 'Lowry',
#   'email': 'blowrypt@studiopress.com',
#   'gender': 'Male',
#   'ip_address': '177.115.204.68'},
#  {'id': 931,
#   'first_name': 'Gwendolin',
#   'last_name': 'Strelitz',
#   'email': 'gstrelitzpu@narod.ru',
#   'gender': 'Female',
#   'ip_address': '146.163.98.16'},
#  {'id': 932,
#   'first_name': 'Bartholomew',
#   'last_name': 'Phlippsen',
#   'email': 'bphlippsenpv@amazon.de',
#   'gender': 'Male',
#   'ip_address': '42.104.250.210'},
#  {'id': 933,
#   'first_name': 'Charlotte',
#   'last_name': 'Vasichev',
#   'email': 'cvasichevpw@dailymotion.com',
#   'gender': 'Female',
#   'ip_address': '63.172.210.80'},
#  {'id': 934,
#   'first_name': 'Lucian',
#   'last_name': 'Dowzell',
#   'email': 'ldowzellpx@hud.gov',
#   'gender': 'Male',
#   'ip_address': '40.76.23.182'},
#  {'id': 935,
#   'first_name': 'Wendy',
#   'last_name': 'Budge',
#   'email': 'wbudgepy@mlb.com',
#   'gender': 'Female',
#   'ip_address': '177.18.214.44'},
#  {'id': 936,
#   'first_name': 'Nickolas',
#   'last_name': 'Leckie',
#   'email': 'nleckiepz@ca.gov',
#   'gender': 'Male',
#   'ip_address': '147.162.86.231'},
#  {'id': 937,
#   'first_name': 'Billie',
#   'last_name': 'Amps',
#   'email': 'bampsq0@soup.io',
#   'gender': 'Male',
#   'ip_address': '151.225.122.40'},
#  {'id': 938,
#   'first_name': 'Steven',
#   'last_name': 'Dearth',
#   'email': 'sdearthq1@forbes.com',
#   'gender': 'Male',
#   'ip_address': '192.54.115.66'},
#  {'id': 939,
#   'first_name': 'Bari',
#   'last_name': 'Twyford',
#   'email': 'btwyfordq2@bandcamp.com',
#   'gender': 'Female',
#   'ip_address': '67.57.130.26'},
#  {'id': 940,
#   'first_name': 'Land',
#   'last_name': 'Heindrick',
#   'email': 'lheindrickq3@deliciousdays.com',
#   'gender': 'Male',
#   'ip_address': '196.205.126.242'},
#  {'id': 941,
#   'first_name': 'Godwin',
#   'last_name': 'Trengrouse',
#   'email': 'gtrengrouseq4@soup.io',
#   'gender': 'Genderqueer',
#   'ip_address': '11.40.150.244'},
#  {'id': 942,
#   'first_name': 'Lishe',
#   'last_name': 'Beche',
#   'email': 'lbecheq5@alexa.com',
#   'gender': 'Polygender',
#   'ip_address': '46.185.200.85'},
#  {'id': 943,
#   'first_name': 'Hannis',
#   'last_name': 'Krikorian',
#   'email': 'hkrikorianq6@reddit.com',
#   'gender': 'Female',
#   'ip_address': '206.67.118.253'},
#  {'id': 944,
#   'first_name': 'Debi',
#   'last_name': 'Athersmith',
#   'email': 'dathersmithq7@sciencedirect.com',
#   'gender': 'Agender',
#   'ip_address': '103.155.145.197'},
#  {'id': 945,
#   'first_name': 'Jeddy',
#   'last_name': 'Addionisio',
#   'email': 'jaddionisioq8@g.co',
#   'gender': 'Male',
#   'ip_address': '104.74.255.95'},
#  {'id': 946,
#   'first_name': 'Gavrielle',
#   'last_name': 'Steanyng',
#   'email': 'gsteanyngq9@tuttocitta.it',
#   'gender': 'Female',
#   'ip_address': '19.90.100.166'},
#  {'id': 947,
#   'first_name': 'Alberta',
#   'last_name': 'Sheraton',
#   'email': 'asheratonqa@phpbb.com',
#   'gender': 'Female',
#   'ip_address': '106.138.73.199'},
#  {'id': 948,
#   'first_name': 'Gannie',
#   'last_name': 'Roslen',
#   'email': 'groslenqb@biblegateway.com',
#   'gender': 'Bigender',
#   'ip_address': '83.145.192.142'},
#  {'id': 949,
#   'first_name': 'Rochette',
#   'last_name': 'Lawlings',
#   'email': 'rlawlingsqc@google.com.au',
#   'gender': 'Female',
#   'ip_address': '98.4.112.23'},
#  {'id': 950,
#   'first_name': 'Carri',
#   'last_name': 'Adamsson',
#   'email': 'cadamssonqd@constantcontact.com',
#   'gender': 'Female',
#   'ip_address': '150.146.95.171'},
#  {'id': 951,
#   'first_name': 'Myrta',
#   'last_name': 'Wormald',
#   'email': 'mwormaldqe@bigcartel.com',
#   'gender': 'Female',
#   'ip_address': '230.56.186.67'},
#  {'id': 952,
#   'first_name': 'Brita',
#   'last_name': 'Artz',
#   'email': 'bartzqf@odnoklassniki.ru',
#   'gender': 'Female',
#   'ip_address': '32.33.123.44'},
#  {'id': 953,
#   'first_name': 'Nert',
#   'last_name': 'Goater',
#   'email': 'ngoaterqg@is.gd',
#   'gender': 'Female',
#   'ip_address': '139.7.152.252'},
#  {'id': 954,
#   'first_name': 'Isa',
#   'last_name': 'Stower',
#   'email': 'istowerqh@ihg.com',
#   'gender': 'Female',
#   'ip_address': '17.188.230.186'},
#  {'id': 955,
#   'first_name': 'Talbot',
#   'last_name': 'Youngs',
#   'email': 'tyoungsqi@dailymail.co.uk',
#   'gender': 'Male',
#   'ip_address': '177.82.45.40'},
#  {'id': 956,
#   'first_name': 'Yvon',
#   'last_name': 'Overell',
#   'email': 'yoverellqj@domainmarket.com',
#   'gender': 'Male',
#   'ip_address': '108.7.165.249'},
#  {'id': 957,
#   'first_name': 'Lucky',
#   'last_name': 'Ethelston',
#   'email': 'lethelstonqk@blog.com',
#   'gender': 'Female',
#   'ip_address': '136.213.185.101'},
#  {'id': 958,
#   'first_name': 'Rahel',
#   'last_name': 'Ikin',
#   'email': 'rikinql@ft.com',
#   'gender': 'Female',
#   'ip_address': '223.83.42.0'},
#  {'id': 959,
#   'first_name': 'Englebert',
#   'last_name': 'Eingerfield',
#   'email': 'eeingerfieldqm@google.com',
#   'gender': 'Male',
#   'ip_address': '106.10.60.0'},
#  {'id': 960,
#   'first_name': 'Marianna',
#   'last_name': 'Geldart',
#   'email': 'mgeldartqn@nature.com',
#   'gender': 'Female',
#   'ip_address': '161.175.90.1'},
#  {'id': 961,
#   'first_name': 'Jamal',
#   'last_name': 'Vanyard',
#   'email': 'jvanyardqo@home.pl',
#   'gender': 'Male',
#   'ip_address': '173.249.154.114'},
#  {'id': 962,
#   'first_name': 'Nadya',
#   'last_name': 'Aughtie',
#   'email': 'naughtieqp@hao123.com',
#   'gender': 'Female',
#   'ip_address': '116.13.20.102'},
#  {'id': 963,
#   'first_name': 'Kellia',
#   'last_name': 'Deacon',
#   'email': 'kdeaconqq@cnbc.com',
#   'gender': 'Female',
#   'ip_address': '182.135.77.10'},
#  {'id': 964,
#   'first_name': 'Rosmunda',
#   'last_name': 'Giannasi',
#   'email': 'rgiannasiqr@networksolutions.com',
#   'gender': 'Female',
#   'ip_address': '68.206.126.1'},
#  {'id': 965,
#   'first_name': 'Chrisy',
#   'last_name': 'Gainseford',
#   'email': 'cgainsefordqs@abc.net.au',
#   'gender': 'Male',
#   'ip_address': '253.122.242.219'},
#  {'id': 966,
#   'first_name': 'Guillermo',
#   'last_name': 'Muggeridge',
#   'email': 'gmuggeridgeqt@cornell.edu',
#   'gender': 'Male',
#   'ip_address': '146.206.245.145'},
#  {'id': 967,
#   'first_name': 'Conroy',
#   'last_name': 'Staneland',
#   'email': 'cstanelandqu@yale.edu',
#   'gender': 'Male',
#   'ip_address': '176.158.13.30'},
#  {'id': 968,
#   'first_name': 'Sileas',
#   'last_name': 'Court',
#   'email': 'scourtqv@netscape.com',
#   'gender': 'Female',
#   'ip_address': '3.246.92.209'},
#  {'id': 969,
#   'first_name': 'Dugald',
#   'last_name': 'Pace',
#   'email': 'dpaceqw@tripadvisor.com',
#   'gender': 'Male',
#   'ip_address': '205.71.77.135'},
#  {'id': 970,
#   'first_name': 'Langsdon',
#   'last_name': 'Cockerton',
#   'email': 'lcockertonqx@dailymotion.com',
#   'gender': 'Male',
#   'ip_address': '27.247.46.254'},
#  {'id': 971,
#   'first_name': 'Audra',
#   'last_name': 'Gurner',
#   'email': 'agurnerqy@cbsnews.com',
#   'gender': 'Female',
#   'ip_address': '145.144.206.93'},
#  {'id': 972,
#   'first_name': 'Roy',
#   'last_name': 'Giffen',
#   'email': 'rgiffenqz@comsenz.com',
#   'gender': 'Male',
#   'ip_address': '123.250.188.207'},
#  {'id': 973,
#   'first_name': 'Glenda',
#   'last_name': 'Cholmondeley',
#   'email': 'gcholmondeleyr0@auda.org.au',
#   'gender': 'Female',
#   'ip_address': '31.20.103.235'},
#  {'id': 974,
#   'first_name': 'Clarissa',
#   'last_name': 'Bendell',
#   'email': 'cbendellr1@trellian.com',
#   'gender': 'Female',
#   'ip_address': '124.206.87.69'},
#  {'id': 975,
#   'first_name': 'Sigfrid',
#   'last_name': 'Bardell',
#   'email': 'sbardellr2@craigslist.org',
#   'gender': 'Male',
#   'ip_address': '251.145.118.101'},
#  {'id': 976,
#   'first_name': 'Warden',
#   'last_name': 'Whorf',
#   'email': 'wwhorfr3@amazonaws.com',
#   'gender': 'Male',
#   'ip_address': '181.231.106.99'},
#  {'id': 977,
#   'first_name': 'Frannie',
#   'last_name': 'Cowill',
#   'email': 'fcowillr4@yolasite.com',
#   'gender': 'Male',
#   'ip_address': '74.194.255.247'},
#  {'id': 978,
#   'first_name': 'Ahmed',
#   'last_name': 'Braunton',
#   'email': 'abrauntonr5@liveinternet.ru',
#   'gender': 'Male',
#   'ip_address': '158.151.91.23'},
#  {'id': 979,
#   'first_name': 'Jorgan',
#   'last_name': 'Pyson',
#   'email': 'jpysonr6@google.it',
#   'gender': 'Male',
#   'ip_address': '74.4.71.163'},
#  {'id': 980,
#   'first_name': 'Selle',
#   'last_name': 'Isoldi',
#   'email': 'sisoldir7@wp.com',
#   'gender': 'Female',
#   'ip_address': '97.14.60.72'},
#  {'id': 981,
#   'first_name': 'Virgie',
#   'last_name': 'Bellefant',
#   'email': 'vbellefantr8@techcrunch.com',
#   'gender': 'Male',
#   'ip_address': '173.61.239.34'},
#  {'id': 982,
#   'first_name': 'Monroe',
#   'last_name': 'Flook',
#   'email': 'mflookr9@goo.gl',
#   'gender': 'Male',
#   'ip_address': '7.40.71.202'},
#  {'id': 983,
#   'first_name': 'Lorinda',
#   'last_name': 'Uc',
#   'email': 'lucra@bbb.org',
#   'gender': 'Female',
#   'ip_address': '116.212.78.243'},
#  {'id': 984,
#   'first_name': 'Jacquelynn',
#   'last_name': 'Gerrelt',
#   'email': 'jgerreltrb@prnewswire.com',
#   'gender': 'Female',
#   'ip_address': '68.125.143.122'},
#  {'id': 985,
#   'first_name': 'Erinn',
#   'last_name': 'Bausmann',
#   'email': 'ebausmannrc@bloglovin.com',
#   'gender': 'Female',
#   'ip_address': '83.183.15.116'},
#  {'id': 986,
#   'first_name': 'Bryce',
#   'last_name': 'Lusgdin',
#   'email': 'blusgdinrd@cargocollective.com',
#   'gender': 'Male',
#   'ip_address': '40.195.4.134'},
#  {'id': 987,
#   'first_name': 'Aurilia',
#   'last_name': 'Palle',
#   'email': 'apallere@chron.com',
#   'gender': 'Female',
#   'ip_address': '140.70.236.253'},
#  {'id': 988,
#   'first_name': 'Fred',
#   'last_name': 'Vasentsov',
#   'email': 'fvasentsovrf@weebly.com',
#   'gender': 'Male',
#   'ip_address': '25.139.74.166'},
#  {'id': 989,
#   'first_name': 'Pammie',
#   'last_name': 'Muzzillo',
#   'email': 'pmuzzillorg@bing.com',
#   'gender': 'Female',
#   'ip_address': '30.147.65.163'},
#  {'id': 990,
#   'first_name': 'Ardath',
#   'last_name': 'Darell',
#   'email': 'adarellrh@hhs.gov',
#   'gender': 'Female',
#   'ip_address': '228.251.75.179'},
#  {'id': 991,
#   'first_name': 'Debera',
#   'last_name': 'Munt',
#   'email': 'dmuntri@mapy.cz',
#   'gender': 'Female',
#   'ip_address': '238.99.92.234'},
#  {'id': 992,
#   'first_name': 'Lydon',
#   'last_name': 'Vernazza',
#   'email': 'lvernazzarj@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '27.232.139.162'},
#  {'id': 993,
#   'first_name': 'Nigel',
#   'last_name': 'Endrici',
#   'email': 'nendricirk@wikispaces.com',
#   'gender': 'Genderfluid',
#   'ip_address': '188.134.213.0'},
#  {'id': 994,
#   'first_name': 'Salvador',
#   'last_name': 'Leser',
#   'email': 'sleserrl@yale.edu',
#   'gender': 'Male',
#   'ip_address': '88.149.66.178'},
#  {'id': 995,
#   'first_name': 'Tommi',
#   'last_name': 'Espinos',
#   'email': 'tespinosrm@europa.eu',
#   'gender': 'Female',
#   'ip_address': '152.100.199.67'},
#  {'id': 996,
#   'first_name': 'Alana',
#   'last_name': 'Paolinelli',
#   'email': 'apaolinellirn@va.gov',
#   'gender': 'Female',
#   'ip_address': '194.49.201.116'},
#  {'id': 997,
#   'first_name': 'Sharl',
#   'last_name': 'Tivolier',
#   'email': 'stivolierro@digg.com',
#   'gender': 'Female',
#   'ip_address': '92.224.179.198'},
#  {'id': 998,
#   'first_name': 'Maryrose',
#   'last_name': 'Simm',
#   'email': 'msimmrp@businesswire.com',
#   'gender': 'Female',
#   'ip_address': '130.215.57.169'},
#  {'id': 999,
#   'first_name': 'Morgen',
#   'last_name': 'Cridlin',
#   'email': 'mcridlinrq@about.com',
#   'gender': 'Male',
#   'ip_address': '152.24.99.209'},
#  {'id': 1000,
#   'first_name': 'Guglielma',
#   'last_name': 'Pender',
#   'email': 'gpenderrr@vistaprint.com',
#   'gender': 'Female',
#   'ip_address': '109.216.217.101'}]

# %%
#data filtering on csv

import pandas as pd

def remove_duplicates_from_csv(input_csv_path, output_csv_path, column_names):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(input_csv_path)

    # Remove duplicates based on the specified column names
    df_no_duplicates = df.drop_duplicates(subset=column_names)

    # Write the DataFrame with duplicates removed to a new CSV file
    df_no_duplicates.to_csv(output_csv_path, index=False)

    return output_csv_path

# Specify the input and output CSV file paths and column names
input_csv_path = "/content/user_data_info.csv"
output_csv_path = "/content/filtered_csv_file.csv"
column_names = ["id", "first_name", "last_name", "email", "gender", "ip_address"]

# Call the function to remove duplicates
new_csv_file_path = remove_duplicates_from_csv(input_csv_path, output_csv_path, column_names)

print(f"Duplicate rows removed. New CSV file saved as '{new_csv_file_path}'")
# Out:
# Duplicate rows removed. New CSV file saved as '/content/filtered_csv_file.csv'
